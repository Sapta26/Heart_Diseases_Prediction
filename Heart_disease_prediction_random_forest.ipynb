# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
open("framingham.csv")
# Out:
# <_io.TextIOWrapper name='framingham.csv' mode='r' encoding='UTF-8'>

# %%
# loading csv data to a pandas DataFrame
heart_data= pd.read_csv("framingham.csv")
heart_data.drop(['education'], axis=1, inplace=True)

# %%
heart_data.head()
# Out:
#    male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39              0         0.0     0.0                0
# 1     0   46              0         0.0     0.0                0
# 2     1   48              1        20.0     0.0                0
# 3     0   61              1        30.0     0.0                0
# 4     0   46              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %%
heart_data.tail()
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 4235     0   48              1        20.0     NaN                0
# 4236     0   44              1        15.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
# 4238     1   40              0         0.0     0.0                0
# 4239     0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 4235             0         0    248.0  131.0   72.0  22.00       84.0
# 4236             0         0    210.0  126.5   87.0  19.16       86.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
# 4238             1         0    185.0  141.0   98.0  25.60       67.0
# 4239             0         0    196.0  133.0   86.0  20.91       85.0
#
#       glucose  TenYearCHD
# 4235     86.0           0
# 4236      NaN           0
# 4237    107.0           0
# 4238     72.0           0
# 4239     80.0           0

# %%
heart_data.shape
# Out:
# (4240, 15)

# %%
heart_data['TenYearCHD'].value_counts()
# Out:
# 0    3596
# 1     644
# Name: TenYearCHD, dtype: int64

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   currentSmoker    4240 non-null   int64
#  3   cigsPerDay       4211 non-null   float64
#  4   BPMeds           4187 non-null   float64
#  5   prevalentStroke  4240 non-null   int64
#  6   prevalentHyp     4240 non-null   int64
#  7   diabetes         4240 non-null   int64
#  8   totChol          4190 non-null   float64
#  9   sysBP            4240 non-null   float64
#  10  diaBP            4240 non-null   float64
#  11  BMI              4221 non-null   float64
#  12  heartRate        4239 non-null   float64
#  13  glucose          3852 non-null   float64
#  14  TenYearCHD       4240 non-null   int64
# dtypes: float64(8), int64(7)
# memory usage: 497.0 KB

# %%
heart_data.isnull().sum()
# Out:
# male                 0
# age                  0
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
count =0
for i in heart_data.isnull().sum(axis=1):
  if i>0 :
    count = count +1
    print('total number of rows with missing values is ', count)
    print ( 'since it is only ', round((count/len(heart_data .index))*100), 'percent of the entire dataset the rows with missing values are excluded')
# Out:
# total number of rows with missing values is  1
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  2
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  3
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  4
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  5
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  6
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  7
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  8
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  9
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  10
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  11
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  12
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  13
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  14
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  15
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  16
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  17
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  18
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  19
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  20
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  21
# since it is only  0 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  22
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  23
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  24
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  25
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  26
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  27
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  28
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  29
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  30
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  31
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  32
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  33
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  34
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  35
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  36
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  37
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  38
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  39
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  40
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  41
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  42
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  43
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  44
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  45
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  46
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  47
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  48
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  49
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  50
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  51
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  52
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  53
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  54
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  55
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  56
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  57
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  58
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  59
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  60
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  61
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  62
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  63
# since it is only  1 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  64
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  65
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  66
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  67
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  68
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  69
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  70
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  71
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  72
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  73
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  74
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  75
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  76
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  77
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  78
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  79
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  80
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  81
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  82
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  83
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  84
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  85
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  86
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  87
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  88
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  89
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  90
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  91
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  92
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  93
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  94
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  95
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  96
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  97
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  98
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  99
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  100
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  101
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  102
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  103
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  104
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  105
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  106
# since it is only  2 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  107
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  108
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  109
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  110
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  111
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  112
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  113
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  114
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  115
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  116
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  117
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  118
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  119
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  120
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  121
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  122
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  123
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  124
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  125
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  126
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  127
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  128
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  129
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  130
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  131
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  132
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  133
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  134
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  135
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  136
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  137
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  138
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  139
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  140
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  141
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  142
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  143
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  144
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  145
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  146
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  147
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  148
# since it is only  3 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  149
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  150
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  151
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  152
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  153
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  154
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  155
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  156
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  157
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  158
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  159
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  160
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  161
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  162
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  163
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  164
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  165
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  166
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  167
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  168
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  169
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  170
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  171
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  172
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  173
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  174
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  175
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  176
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  177
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  178
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  179
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  180
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is  181
# since it is only  4 percent of the entire dataset the rows with missing values are excluded
# total number of rows with missing values is
000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol        sysBP  \
# count      3751.000000   3751.000000  3751.000000  3751.000000  3751.000000
# mean          0.005599      0.311917     0.027193   236.928019   132.368435
# std           0.074623      0.463338     0.162666    44.611594    22.046522
# min           0.000000      0.000000     0.000000   113.000000    83.500000
# 25%           0.000000      0.000000     0.000000   206.000000   117.000000
# 50%           0.000000      0.000000     0.000000   234.000000   128.000000
# 75%           0.000000      1.000000     0.000000   264.000000   144.000000
# max           1.000000      1.000000     1.000000   696.000000   295.000000
#
#              diaBP          BMI    heartRate      glucose   TenYearCHD
# count  3751.000000  3751.000000  3751.000000  3751.000000  3751.000000
# mean     82.938550    25.808288    75.704079    81.880032     0.152493
# std      11.932779     4.065599    11.956382    23.882233     0.359546
# min      48.000000    15.540000    44.000000    40.000000     0.000000
# 25%      75.000000    23.085000    68.000000    71.000000     0.000000
# 50%      82.000000    25.410000    75.000000    78.000000     0.000000
# 75%      90.000000    28.060000    82.000000    87.000000     0.000000
# max     142.500000    56.800000   143.000000   394.000000     1.000000

# %%
# checking the distribution of the target variable after null entries excludation
heart_data['TenYearCHD'].value_counts()
# Out:
# 0    3179
# 1     572
# Name: TenYearCHD, dtype: int64

# %% [markdown]
# It means there are 3179 people with defective heart and 572 people with risk of heart disease.
#
# 1---> defective heart
#
# 0---< healthy heart

# %%
X= heart_data.drop(columns='TenYearCHD',axis=1)
Y=heart_data['TenYearCHD']

# %%
print(X)
# Out:
#       male  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0        1   39              0         0.0     0.0                0
# 1        0   46              0         0.0     0.0                0
# 2        1   48              1        20.0     0.0                0
# 3        0   61              1        30.0     0.0                0
# 4        0   46              1        23.0     0.0                0
# ...    ...  ...            ...         ...     ...              ...
# 4233     1   50              1         1.0     0.0                0
# 4234     1   51              1        43.0     0.0                0
# 4237     0   52              0         0.0     0.0                0
# 4238     1   40              0         0.0     0.0                0
# 4239     0   39              1        30.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose
# 0                0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0     85.0
# ...            ...       ...      ...    ...    ...    ...        ...      ...
# 4233             1         0    313.0  179.0   92.0  25.97       66.0     86.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0     68.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0    107.0
# 4238             1         0    185.0  141.0   98.0  25.60       67.0     72.0
# 4239             0         0    196.0  133.0   86.0  20.91       85.0     80.0
#
# [3751 rows x 14 columns]

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4233    1
# 4234    0
# 4237    0
# 4238    0
# 4239    0
# Name: TenYearCHD, Length: 3751, dtype: int64

# %%
X_train, X_test, Y_train, Y_test= train_test_split (X, Y, test_size=0.25, random_state=5)

# %%
print (X.shape, X_train.shape,X_test.shape)
# Out:
# (3751, 14) (2813, 14) (938, 14)

# %%
model=RandomForestClassifier()

# %%
# training the LogisticRegression model with Training data
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
# # accuracy on Training data
# X_train_prediction=model.predict(X_train)
# training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
# accuracy on Test data
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)
print("accuracy on test data:", test_data_accuracy)
# Out:
# accuracy on test data: 0.8720682302771855

# %% [markdown]
# Accuracy calculation

# %%
print("accuracy on test data:",model.score(X_test,Y_test))
# Out:
# accuracy on test data: 0.8720682302771855

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,X_test_prediction)
conf_matrix=pd.DataFrame(data=cm,columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
plt.figure(figsize=(8,5))
sns.heatmap(conf_matrix,annot=True,fmt='d',cmap="YlGnBu")
# Out:
# <Axes: >

# %%
# # accuracy on Test data
# X_test_prediction=model.predict(X_test)
# test_data_accuracy=accuracy_score(X_test_prediction,Y_test)
# print("accuracy on test data:", test_data_accuracy)

# %%
# input_data=(46,2,1,20,0,0,0,0,291,112,78,23.38,80,89)

# # change the input data to a numpy array
# input_data_as_numpy_array=np.asarray(input_data)

# # reshape the numpy array as we are predecting for one instance
# input_data_reshaped= input_data_as_numpy_array.reshape(1,-1)

# prediction = model.predict(input_data_reshaped)
# print(prediction)

# if(prediction[0]==0):
#   print("The person doesn't have any heart diseases")
# else:
#   print("The person has heart disases")
# Out:
# [0]
# The person doesn't have any heart diseases
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
